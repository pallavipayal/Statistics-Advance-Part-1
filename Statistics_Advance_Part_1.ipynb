# %% [markdown]
# #Statistics Advance Part 1
# ##Assignment Questions

# %% [markdown]
# ###1.What is a random variable in probability theory?

# %% [markdown]
# => In probability theory, a random variable is essentially a way to assign numerical values to the outcomes of a random experiment.
#
#  Imagine you're flipping a coin. The outcomes are "heads" or "tails." You can define a random variable X that assigns the value 1 to "heads" and 0 to "tails." Now, you can talk about the probability of X being 1 or 0.

# %% [markdown]
# ###2.What are the types of random variables?

# %% [markdown]
# => In probability and statistics, random variables are categorized primarily into two main types:
#
# Discrete Random Variables:
#
# These variables can only take on a countable number of distinct values. This means the values can be listed, even if the list goes on infinitely.
# Examples:
# The number of heads in a series of coin tosses.
# The number of defective items in a batch.
# The number of cars that pass through an intersection in an hour.
#
# Continuous Random Variables:
#
# These variables can take on any value within a given range or interval. Essentially, they can take on an infinite number of possible values.
# Examples:
# A person's height or weight.
# The temperature of a room.
# The time it takes to complete a task.

# %% [markdown]
# ###3.What is the difference between discrete and continuous distributions?

# %% [markdown]
# => The key difference between discrete and continuous distributions lies in the nature of the values that the random variables can take:
#
# Discrete Distributions:
#
# Values:
# These distributions deal with random variables that can only take on a countable number of distinct values. This means you can list the possible values, even if the list is infinitely long.
# Think of "counting" things.
#
# Probability:
# Probabilities are assigned to individual values. For example, you can say "the probability of getting exactly 3 heads is 0.2."
# They are often represented by probability mass functions (PMFs).
#
#  Continuous Distributions:
#
# Values:
# These distributions deal with random variables that can take on any value within a given range. This means there are infinitely many possible values.
# Think of "measuring" things.
#
# Probability:
# Probabilities are assigned to ranges of values, not to individual values. The probability of a continuous random variable taking on a precise, specific value is essentially zero.
# They are described by probability density functions (PDFs).

# %% [markdown]
# ###4.What are probability distribution functions (PDF)?

# %% [markdown]
# => A probability distribution describes the likelihood of different outcomes in a random experiment.
#  It essentially tells you how probabilities are distributed across the possible values of a random variable
#
# or Continuous Random Variables:
# The term "probability density function" (PDF) is used.
# A PDF, often denoted as f(x), represents the relative likelihood of a continuous random variable taking on a given value.
# Crucially, the PDF itself doesn't give you the probability of a specific value; instead, the probability of a variable falling within a certain range is determined by calculating the area under the PDF curve over that range.
# In other words, probabilities are found by integrating the PDF.

# %% [markdown]
# ###5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?

# %% [markdown]
# => Probability Distribution Function (PDF):
# For continuous random variables, the PDF (or probability density function) describes the likelihood of the random variable taking on a specific value. It provides the "density" of probability at each point.
# For discrete random variables, it is called a Probability Mass Function (PMF) and gives the actual probability of the random variable taking on a specific value.
#
# The total area under a continuous PDF curve is always 1.
# The sum of all the probabilities of a discrete PMF is always 1.
#
# Cumulative Distribution Function (CDF):   The CDF gives the probability that a random variable will take on a value less than or equal to a specific value.
#  In essence, it accumulates the probabilities up to that point.
# The CDF is always non-decreasing.
# It ranges from 0 to 1.
# It can be used for both discrete and continuous random variables

# %% [markdown]
# ###6.What is a discrete uniform distribution?

# %% [markdown]
# => The discrete uniform distribution is a probability distribution where a finite number of outcomes are equally likely to occur.
#
# Finite Outcomes:
# It deals with a situation where there's a specific, countable number of possible results.
# Equal Probability:
# Each of those possible outcomes has the same chance of happening.

# %% [markdown]
# ###7.What are the key properties of a Bernoulli distribution?

# %% [markdown]
# => The Bernoulli distribution is a fundamental discrete probability distribution that models a single trial with only two possible outcomes.
#
# Binary Outcomes:
# It describes a random experiment with only two possible outcomes, often labeled as "success" and "failure."
# These outcomes are typically represented numerically as 1 (for success) and 0 (for failure).
# Probability of Success (p):
# The distribution is characterized by a single parameter, 'p,' which represents the probability of success.
# The probability of failure is then '1 - p,' often denoted as 'q.'
# Probability Mass Function (PMF):
# The PMF defines the probability of each outcome:
# P(X = 1) = p
# P(X = 0) = 1 - p

# %% [markdown]
# ###8. What is the binomial distribution, and how is it used in probability?

# %% [markdown]
# => The binomial distribution describes the probability of obtaining a certain number of "successes" in a fixed number of independent trials.
# Each trial has only two possible outcomes: "success" or "failure."
# The probability of success remains constant for every trial.
#
# The binomial distribution is widely used to model and analyze various real-world scenarios involving binary outcomes.
#
# Quality Control:
# Manufacturers use it to determine the probability of defective items in a production batch.
#
# Medical Research:
# It's used to analyze the effectiveness of treatments, such as the probability of a patient recovering from a disease.
#
# Opinion Polls and Surveys:
# It helps determine the probability of a certain number of people holding a particular opinion.
#
# Games of Chance:
# It's used to calculate the probabilities of winning or losing in games involving coin flips, dice rolls, or card draws.
#
# Finance:
# It is used in financial modeling, for example in option pricing models.

# %% [markdown]
# ###9. What is the Poisson distribution and where is it applied?

# %% [markdown]
# =>The Poisson distribution is a discrete probability distribution that expresses the probability of a given number of events occurring
#  in a fixed interval of time or space if these events occur with a known constant mean rate and independently of the time since the last event.
#
# The Poisson distribution is widely used to model various real-world phenomena, including:
#
# Telecommunications:
# Modeling the number of phone calls received at a call center within a specific time period.
#
# Traffic Flow:
# Analyzing the number of vehicles passing through a toll booth in a given time interval.
#
# Healthcare:
# Predicting the number of patients arriving at an emergency room within an hour.   Modeling the number of cases of a rare disease within a population.
#
# Quality Control:
# Determining the number of defects found in a manufactured product.
#
# Insurance:Estimating the number of insurance claims within a certain period.
#
# Ecology:
# Counting the number of animals in a specific area.
# Finance:
# Modeling the number of market shocks within a time period.

# %% [markdown]
# ###10.What is a continuous uniform distribution?

# %% [markdown]
# => In probability theory and statistics, a continuous uniform distribution describes a situation where all outcomes within a specific range are equally likely.
#
# the continuous uniform distribution provides a model for situations where there's no reason to believe that any particular outcome within a range is more likely than any other.

# %% [markdown]
# ###11.What are the characteristics of a normal distribution?

# %% [markdown]
# => The normal distribution, also known as the Gaussian distribution, is a very important probability distribution in statistics.
#
# Characteristics:
#
# Bell-Shaped Curve:
# When graphed, the normal distribution forms a symmetrical, bell-shaped curve.
# Symmetry:
# The distribution is perfectly symmetrical around its mean. This means that the left and right halves of the curve are mirror images of each other.
# Mean, Median, and Mode are Equal:
# In a perfectly normal distribution, the mean (average), median (middle value), and mode (most frequent value) are all the same.
#
#  They are located at the center of the distribution.

# %% [markdown]
# ###12.What is the standard normal distribution, and why is it important?

# %% [markdown]
# => It's a normal distribution with a mean of 0 and a standard deviation of 1.
# This standardization allows for easy comparison and analysis of data from different normal distributions.
# Values within a standard normal distribution are often referred to as "z-scores."
# Importance:
#
# Standardization:
# It allows us to standardize any normal distribution, converting its values into z-scores. This makes it possible to compare data from different distributions with varying means and standard deviations.
# Probability Calculations:
# Tables and software are readily available to calculate probabilities associated with the standard normal distribution. This allows us to easily determine the likelihood of certain values occurring within any normally distributed dataset.
# Hypothesis Testing:
# The standard normal distribution is fundamental in hypothesis testing, particularly in z-tests. These tests are used to determine if a sample mean significantly differs from a population mean.
# Statistical Inference:
# It's essential for statistical inference, enabling us to make predictions and draw conclusions about populations based on sample data.
# Simplifying Calculations:
# By converting normal distributions into the standard normal distribution, calculations become simpler and more consistent.
# Z-tables:
# The standard normal distribution is used in conjunction with Z-tables, which provide the area under the curve for different z-scores. This is extremely important when trying to find probabilities.

# %% [markdown]
# ###13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?

# %% [markdown]
# => The Central Limit Theorem (CLT) is a cornerstone of probability theory and statistics. It states that, under certain conditions, the distribution of the sample mean (or sum) of a large number of independent, identically distributed random variables will be approximately normally distributed, regardless of the original distribution's shape.

# %% [markdown]
# ###14.  How does the Central Limit Theorem relate to the normal distribution?

# %% [markdown]
# => Sample Mean Distribution:
# The CLT describes the shape of the sampling distribution of the mean. This is the distribution you'd get if you took many samples from a population, calculated the mean of each sample, and then plotted those means. The CLT says this distribution will be approximately normal.
# Standard Error:
# The CLT also specifies the standard deviation of this sampling distribution, which is called the standard error. It's calculated as the population standard deviation divided by the square root of the sample size. The normal distribution of the sample means is centered on the populations true mean, and has a standard deviation of the standard error.
# Statistical Inference:
# Because of the CLT, we can use the normal distribution to calculate probabilities and construct confidence intervals for population means, even if the population itself isn't normally distributed. This is fundamental to statistical inference.

# %% [markdown]
# ###15.What is the application of Z statistics in hypothesis testing?

# %% [markdown]
# => Comparing Sample Means to Population Means:
# A primary use of the Z-statistic is to test whether the mean of a sample is significantly different from a known population mean.
# This is particularly relevant when the population standard deviation is known.
# Large Sample Sizes:
# The Z-test is most appropriate when dealing with large sample sizes (typically n ≥ 30).
# This is because, according to the Central Limit Theorem, the distribution of sample means approaches a normal distribution as the sample size increases.
# Known Population Standard Deviation:
# A crucial requirement for using a Z-test is that the population standard deviation must be known. If it's unknown, a t-test is generally used instead.
# Hypothesis Testing Steps:
# In hypothesis testing, the Z-statistic is used to calculate a test statistic, which is then compared to a critical value from the standard normal distribution.
# This comparison helps determine whether to reject the null hypothesis (the hypothesis of no difference) in favor of the alternative hypothesis.
# Determining Statistical Significance:
# By calculating the Z-statistic and comparing it to critical values, researchers can determine the statistical significance of their findings.
# This helps them assess the likelihood that the observed results are due to chance.
# Z-tests for proportions:
# Z tests are also used to compare proportions of different groups.

# %% [markdown]
# ###16.  How do you calculate a Z-score, and what does it represent?

# %% [markdown]
# Calculating a Z-score is a straightforward process, and it provides valuable information about the position of a data point within a distribution. Here's a breakdown:
#
# Calculation:
#
# The formula for calculating a Z-score is:
#
# Z= (X−μ)/σ
# ​
#
#
# Where:
#
# Z is the Z-score.
# X is the individual data point you want to standardize.
# μ (mu) is the mean of the population or sample.
# σ (sigma) is the standard deviation of the population or sample.
#
# It represents:
#
# Standard Deviations from the Mean:
# A Z-score tells you how many standard deviations a particular data point is away from the mean of its distribution.
# A positive Z-score indicates that the data point is above the mean.
# A negative Z-score indicates that the data point is below the mean.
# A Z-score of 0 means the data point is exactly equal to the mean.
# Standardized Value:
# By converting data points to Z-scores, you standardize them, allowing you to compare values from different distributions.
# This is particularly useful when dealing with data that has different units or scales.
# Probability and Percentiles:
# Z-scores are used in conjunction with the standard normal distribution to determine probabilities and percentiles.
# By looking up a Z-score in a Z-table (standard normal distribution table), you can find the area under the curve to the left or right of that Z-score, which represents the probability of observing a value less than or greater than the corresponding data point.
# This is used to find percentiles.
# Outlier Detection:
# Z-scores can help identify outliers.
#
#  Data points with Z-scores that are far from zero (typically beyond ±2 or ±3) are considered unusual and may warrant further investigation.

# %% [markdown]
# ###17.What are point estimates and interval estimates in statistics?

# %% [markdown]
# => Point Estimates:
# A point estimate is a single value that is used to approximate an unknown population parameter.
# It's essentially our "best guess" for the parameter.
#
# Interval Estimates:
# An interval estimate provides a range of values within which the population parameter is likely to fall.
# It offers a measure of the uncertainty associated with the estimate.

# %% [markdown]
# ###18.What is the significance of confidence intervals in statistical analysis?

# %% [markdown]
# => ignificance:
#
# Quantifying Uncertainty:
# Confidence intervals address the inherent uncertainty in estimating population parameters from sample data.
# They acknowledge that sample statistics are subject to random variation and may not perfectly reflect the true population values.
# Providing a Range of Plausible Values:
# Instead of offering a single point estimate, confidence intervals provide a range within which the population parameter is likely to lie.
# This range gives a more realistic picture of the parameter's possible values.
# Expressing Confidence Level:
# Confidence intervals are associated with a confidence level (e.g., 95%, 99%).
# This level indicates the percentage of times that the interval is expected to contain the true population parameter if the sampling process were repeated many times.
# Facilitating Informed Decision-Making:
# Confidence intervals aid in making informed decisions by providing a sense of the precision and reliability of estimates.
# They help assess the practical significance of findings and avoid over-interpreting point estimates.
# Hypothesis Testing and Statistical Inference:
# Confidence intervals are closely related to hypothesis testing.
# If a hypothesized value falls outside the confidence interval, it suggests evidence against the null hypothesis.
# Confidence intervals are an important tool in statistical inference.
# Assessing Statistical Significance:
# While p-values are often used for statistical significance, confidence intervals provide additional context. For example, a confidence interval that is very wide indicates that although a result might be statistically significant, the actual effect could be very small.
# Practical Significance:
# Confidence intervals also help to show practical significance. A result might be statistically significant, but the confidence interval allows a researcher to see if the range of plausible values are actually meaningful in the real world.

# %% [markdown]
# ###19. What is the relationship between a Z-score and a confidence interval?

# %% [markdown]
# => The Z-score and confidence intervals are closely related, especially when dealing with normally distributed data or large sample sizes.
#
# Z-scores provide the critical values needed to define the width of a confidence interval.
# The Z-score, along with the standard error, determines the margin of error, which is crucial for constructing the confidence interval.
# Essentially, the Z-score translates the desired confidence level into a standardized measure of how far the interval extends from the sample mean.

# %% [markdown]
# ###20.  How are Z-scores used to compare different distributions?

# %% [markdown]
# => Z-scores are a powerful tool for comparing data points across different distributions, even when those distributions have different means and standard deviations.
#
# Direct Comparison:
# By converting data points to Z-scores, you can directly compare them, even if they come from different distributions.
# A higher Z-score indicates a relatively higher value within its distribution.
# Identifying Relative Performance:
# For example, if you want to compare a student's performance on two different tests with different scoring scales, you can calculate their Z-scores for each test.
# The Z-scores will tell you how well the student performed relative to the other students who took each test.
# Outlier Detection:
# Z-scores are useful for identifying outliers across different distributions.
# A data point with a Z-score that is far from zero (e.g., beyond ±3) is considered an outlier, regardless of the original distribution.

# %% [markdown]
# ###21.What are the assumptions for applying the Central Limit Theorem?

# %% [markdown]
# => Assumptions:
#
# Independence:
# The observations in the sample must be independent of each other. This means that the value of one observation should not influence the value of another.
# In practical terms, this often implies that the data is collected through random sampling.
# Identical Distribution:
# The observations in the sample must be drawn from the same probability distribution.
# This means that all data points should have the same underlying characteristics.
# Finite Variance:
# The population from which the samples are drawn must have a finite variance.
# In simpler terms, the data should not be infinitely spread out.
# Sample Size (n):
# While not a strict assumption, the CLT works best with sufficiently large sample sizes.
# "Large" is somewhat subjective, but a common rule of thumb is that n ≥ 30 is generally considered large enough for the CLT to hold. However, for distributions that are already somewhat symmetrical, the CLT can work with smaller sample sizes. For strongly skewed distributions, larger sample sizes may be needed.

# %% [markdown]
# ###22. What is the concept of expected value in a probability distribution?

# %% [markdown]
# => In probability theory, the concept of expected value is crucial for understanding the average outcome of a random variable.
# The expected value is not necessarily a value that the random variable will ever actually take.
# It's a theoretical average that represents the long-run mean.
# It's used in various fields, including:
# Finance (to calculate the expected return of an investment)
# Gambling (to determine the average outcome of a game)
# Insurance (to calculate expected payouts)

# %% [markdown]
# ###23. How does a probability distribution relate to the expected outcome of a random variable?

# %% [markdown]
# => A probability distribution and the expected outcome (expected value) of a random variable are intrinsically linked.
#
# The probability distribution provides the framework for understanding the likelihood of different outcomes.
# The expected value is a calculation that uses the information provided by the probability distribution to determine the average outcome of the random variable.
# Therefore, the probability distribution is the source of the information, and the expected value is a calculation that summarizes the average outcome, based on that information.

# %% [markdown]
# ##Practical

# %%
#1.
import random

random_value = random.randint(1, 100)

print("The random value is:", random_value)
# Out:
# The random value is: 26

# %%
#2.
import numpy as np
import matplotlib.pyplot as plt


low = 1
high = 6
samples = np.random.randint(low, high, size=1000)

values, counts = np.unique(samples, return_counts=True)

pmf = counts / len(samples)

plt.bar(values, pmf, width=0.5, color='skyblue', edgecolor='black')

plt.xlabel('Value')
plt.ylabel('Probability')
plt.title('Probability Mass Function of Discrete Uniform Distribution')

plt.show()

# %%
#3.
def bernoulli_pdf(x, p):
    """
    Calculate the Probability Distribution Function (PDF) of a Bernoulli distribution.

    Parameters:
    - x: The outcome (0 or 1).
    - p: The probability of success (0 <= p <= 1).

    Returns:
    - The probability P(X = x).
    """
    if x not in [0, 1]:
        raise ValueError("x must be either 0 or 1.")
    if p < 0 or p > 1:
        raise ValueError("p must be between 0 and 1.")

    return p**x * (1 - p)**(1 - x)


p = 0.7
x = 1

print(f"P(X = {x}) = {bernoulli_pdf(x, p)}")

x = 0
print(f"P(X = {x}) = {bernoulli_pdf(x, p)}")
# Out:
# P(X = 1) = 0.7
# P(X = 0) = 0.30000000000000004

# %%
#4.
import numpy as np
import matplotlib.pyplot as plt


n = 10
p = 0.5
size = 10000
samples = np.random.binomial(n, p, size)

plt.hist(samples, bins=np.arange(n+2) - 0.5, density=True, alpha=0.75, color='skyblue', edgecolor='black')

plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution Histogram (n={n}, p={p})')


plt.show()

# %%
#5

import numpy as np
import matplotlib.pyplot as plt

lambda_ = 5
size = 10000
samples = np.random.poisson(lambda_, size)

plt.hist(samples, bins=range(min(samples), max(samples) + 1), density=True, alpha=0.75, color='skyblue', edgecolor='black')

plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.title(f'Poisson Distribution (λ={lambda_})')

plt.show()

# %%
#6
import numpy as np
import matplotlib.pyplot as plt

a = 1
b = 6

outcomes = np.arange(a, b + 1)

cdf_values = (outcomes - a + 1) / (b - a + 1)

plt.step(outcomes, cdf_values, where='post', color='skyblue', linestyle='-', linewidth=2, marker='o', markersize=6)

plt.xlabel('Outcome')
plt.ylabel('CDF')
plt.title(f'Cumulative Distribution Function (CDF) of Discrete Uniform Distribution\nfrom {a} to {b}')

plt.grid(True)

plt.show()

# %%
#7
import numpy as np
import matplotlib.pyplot as plt

low = 0
high = 10
size = 10000

samples = np.random.uniform(low, high, size)

plt.hist(samples, bins=50, density=True, alpha=0.6, color='skyblue', edgecolor='black')

plt.axhline(y=1 / (high - low), color='red', linestyle='--', label='PDF')

plt.xlabel('Value')
plt.ylabel('Density')
plt.title(f'Continuous Uniform Distribution\nInterval: [{low}, {high})')
plt.legend()

plt.show()

# %%
#8
import numpy as np
import matplotlib.pyplot as plt

mean = 0
std_dev = 1
num_samples = 10000
samples = np.random.normal(loc=mean, scale=std_dev, size=num_samples)

plt.hist(samples, bins=50, density=True, alpha=0.6, color='skyblue', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Density')
plt.title(f'Histogram of {num_samples} Samples from N({mean}, {std_dev}^2)')

plt.show()

# %%
#9
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

def calculate_and_plot_z_scores(data):
    """
    Calculate Z-scores for a given dataset and plot the original data alongside its Z-scores.

    Parameters:
    - data: A list or NumPy array of numerical values.
    """
    data = np.asarray(data)

    z_scores = zscore(data)

    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.plot(data, marker='o', linestyle='-', color='b', label='Original Data')
    plt.xlabel('Index')
    plt.ylabel('Value')
    plt.title('Original Data')
    plt.grid(True)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(z_scores, marker='o', linestyle='-', color='r', label='Z-Scores')
    plt.xlabel('Index')
    plt.ylabel('Z-Score')
    plt.title('Z-Scores')
    plt.grid(True)
    plt.legend()

    plt.tight_layout()
    plt.show()

    return z_scores

data = [10, 20, 20, 30, 40, 50, 60, 70, 80, 90]
z_scores = calculate_and_plot_z_scores(data)
print("Z-Scores:", z_scores)
# Out:
# Z-Scores: [-1.41784308 -1.03464225 -1.03464225 -0.65144142 -0.26824058  0.11496025
#   0.49816108  0.88136192  1.26456275  1.64776358]

# %%
#10
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)

population_size = 100000
sample_sizes = [5, 30, 100]
n_samples = 1000
scale = 2
population = np.random.exponential(scale=scale, size=population_size)

def sample_means(population, n_samples, sample_size):
    means = []
    for _ in range(n_samples):
        sample = np.random.choice(population, size=sample_size)
        means.append(np.mean(sample))
    return means

plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
sns.histplot(population, bins=50, kde=True, color='skyblue')
plt.title('Population Distribution (Exponential)', fontsize=14)
plt.xlabel('Value', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

for i, sample_size in enumerate(sample_sizes, 2):
    means = sample_means(population, n_samples, sample_size)
    plt.subplot(2, 2, i)
    sns.histplot(means, bins=50, kde=True)
    plt.title(f'Sample Means (n={sample_size})', fontsize=14)
    plt.xlabel('Sample Mean', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)

plt.tight_layout()
plt.show()

# %%
#11
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)

population_size = 100000
sample_sizes = [5, 30, 100]
n_samples = 1000

population = np.random.uniform(low=0, high=10, size=population_size)

def sample_means(population, n_samples, sample_size):
    means = []
    for _ in range(n_samples):
        sample = np.random.choice(population, size=sample_size)
        means.append(np.mean(sample))
    return means

plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
sns.histplot(population, bins=50, kde=True, color='skyblue')
plt.title('Population Distribution (Uniform)', fontsize=14)
plt.xlabel('Value', fontsize=12)
plt.ylabel('Frequency', fontsize=12)

for i, sample_size in enumerate(sample_sizes, 2):
    means = sample_means(population, n_samples, sample_size)
    plt.subplot(2, 2, i)
    sns.histplot(means, bins=50, kde=True)
    plt.title(f'Sample Means (n={sample_size})', fontsize=14)
    plt.xlabel('Sample Mean', fontsize=12)
    plt.ylabel('Frequency', fontsize=12)

plt.tight_layout()
plt.show()

# %%
#12
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():

    x = np.linspace(-5, 5, 1000)

    y = norm.pdf(x, loc=0, scale=1)

    plt.figure(figsize=(8, 6))
    plt.plot(x, y, label="Standard Normal Distribution (mean=0, std=1)", color='blue')
    plt.fill_between(x, y, alpha=0.2, color='blue')
    plt.title("Standard Normal Distribution (mean = 0, std = 1)")
    plt.xlabel("x")
    plt.ylabel("Probability Density")
    plt.grid(True)
    plt.legend()
    plt.show()

plot_standard_normal_distribution()

# %%
#13
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

def binomial_distribution(n, p, size):
    random_vars = np.random.binomial(n, p, size)

    prob = binom.pmf(random_vars, n, p)

    print("Random Variables: ", random_vars)
    print("Corresponding Probabilities: ", prob)

    plt.figure(figsize=(8, 6))
    plt.hist(random_vars, bins=np.arange(-0.5, n+1.5, 1), density=True, alpha=0.7, color='skyblue', edgecolor='black', label="Random Variables")

    x = np.arange(0, n+1)
    y = binom.pmf(x, n, p)
    plt.plot(x, y, 'ro-', label="Binomial PMF")

    plt.title(f"Binomial Distribution PMF (n={n}, p={p})")
    plt.xlabel("Number of Successes")
    plt.ylabel("Probability")
    plt.legend()
    plt.grid(True)
    plt.show()

n = 10
p = 0.5
size = 1000

binomial_distribution(n, p, size)
# Out:
# Random Variables:  [ 5  7  5  3  4  7  5  6  5  6  5  7  7  6  7  3  5  6  2  5  3  4  6  6
#   4  7  4  5  8  7  4  4  5  2  3  7  5  4  6  4  3  5  4  8  5  5  6  5
#   6  2  7  3  4  4  6  3  6  5  4  5  4  5  7  6  2  4  7  6  6  7  5  3
#   5  4  3  6  7  4  1  9  4  7  3  6  5  5  6  6  6  6  2  6  2  6  6  5
#   4  3  5  3  5  3  4  7  7  4  6  6  7  5  5  6  5  5  4  4  6  4  5  4
#   4  3  6  5  6  5  5  5  5  5  5  4  5  6  1  5  2  8  4  6  4  5  6  2
#   5  5  5  4  6  6  4  3  8  8  6  5  5  9  9  2  3  8  4  7  5  6  5  4
#   4  5  3  6  6  4  4  6  4  6  7  2  7  5  4  7  5  6  3  7  4  9  6  4
#   5  5  6  7  5  6  5  9  7  6  6  6  4  4  6  3  5  3  5  7  6  4  1  3
#   3  7  6  5  7  5  4  4  5  5  3  6  5  5  6  5  5  4  8  6  6  2  5  6
#   6  7  6  5  4  5  5  4  2  5  6  7  1  4  3  8  5  3  6  7  4  7  6  2
#   4  6  6  7  5  4  3  3  3  5  4  1  8  7  3  3  7  4  2  5  2  5  4  6
#   5  9  5  4  6  7  6  6  3  4  4  6  3  2  3  4  6  5  6  6  4  5  7  5
# ...

# %%
#14
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(X, mean, std_dev):
    """
    Calculate the Z-score for a given data point X.
    """
    return (X - mean) / std_dev

def plot_comparison(X, mean, std_dev):
    """
    Plot the standard normal distribution and show the Z-score comparison.
    """
    Z = calculate_z_score(X, mean, std_dev)

    x_values = np.linspace(-4, 4, 1000)
    y_values = norm.pdf(x_values, loc=0, scale=1)

    plt.plot(x_values, y_values, label="Standard Normal Distribution", color='blue')

    plt.axvline(Z, color='red', linestyle='--', label=f'Z-score = {Z:.2f}')
    plt.fill_between(x_values, y_values, where=(x_values <= Z), color='red', alpha=0.2)

    plt.title(f"Standard Normal Distribution with Z-score for X={X}")
    plt.xlabel("Z-value")
    plt.ylabel("Probability Density")
    plt.legend()
    plt.grid(True)
    plt.show()

    return Z

X = 75
mean = 70
std_dev = 5

Z = calculate_z_score(X, mean, std_dev)
print(f"Z-score for X = {X}: {Z:.2f}")

plot_comparison(X, mean, std_dev)
# Out:
# Z-score for X = 75: 1.00
# 1.0

# %%
#15
import numpy as np
import scipy.stats as stats

def z_test(sample_data, population_mean, population_std, alpha=0.05):
    """
    Perform a Z-test for a sample data against a population mean and standard deviation.

    Parameters:
    sample_data (array-like): The sample data.
    population_mean (float): The population mean (under the null hypothesis).
    population_std (float): The population standard deviation.
    alpha (float): The significance level (default is 0.05).

    Returns:
    result (str): The conclusion of the hypothesis test ("Reject H0" or "Fail to reject H0").
    """
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)

    z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    z_critical = stats.norm.ppf(1 - alpha / 2)

    p_value = 2 * (1 - stats.norm.cdf(abs(z_stat)))

    if abs(z_stat) > z_critical:
        result = "Reject H0"
    else:
        result = "Fail to reject H0"

    print(f"Sample Mean: {sample_mean}")
    print(f"Z-statistic: {z_stat}")
    print(f"Critical Z-value: {z_critical}")
    print(f"P-value: {p_value}")
    print(f"Result: {result}")

    return result

sample_data = np.array([85, 87, 90, 92, 88, 85, 93, 84, 89, 91])

population_mean = 90
population_std = 5

z_test(sample_data, population_mean, population_std)
# Out:
# Sample Mean: 88.4
# Z-statistic: -1.0119288512538778
# Critical Z-value: 1.959963984540054
# P-value: 0.31157207331441006
# Result: Fail to reject H0
# 'Fail to reject H0'

# %%
#16
import numpy as np
import scipy.stats as stats

def confidence_interval(sample_data, confidence_level=0.95):
    """
    Calculate the confidence interval for the sample data.

    Parameters:
    sample_data (array-like): The sample data.
    confidence_level (float): The confidence level (default is 0.95).

    Returns:
    (tuple): The confidence interval (lower bound, upper bound).
    """
    sample_mean = np.mean(sample_data)
    sample_std = np.std(sample_data, ddof=1)
    sample_size = len(sample_data)

    df = sample_size - 1

    t_critical = stats.t.ppf((1 + confidence_level) / 2, df)

    se = sample_std / np.sqrt(sample_size)

    margin_of_error = t_critical * se

    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

sample_data = np.array([15, 17, 19, 20, 22, 24, 23, 18, 21, 20])

lower, upper = confidence_interval(sample_data, confidence_level=0.95)
print(f"95% Confidence Interval: ({lower:.2f}, {upper:.2f})")
# Out:
# 95% Confidence Interval: (17.92, 21.88)

# %%
#17
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_normal_pdf(mean, std_dev, x_range=(-5, 5), num_points=1000):
    """
    Calculate and plot the Probability Density Function (PDF) of a normal distribution.

    Parameters:
    - mean: The mean of the normal distribution.
    - std_dev: The standard deviation of the normal distribution.
    - x_range: The range of x-values to plot the PDF over.
    - num_points: The number of points to use for the x-axis (default is 1000).
    """
    x_values = np.linspace(x_range[0], x_range[1], num_points)

    pdf_values = norm.pdf(x_values, loc=mean, scale=std_dev)

    plt.figure(figsize=(8, 6))
    plt.plot(x_values, pdf_values, label=f'Normal Distribution\nMean={mean}, Std Dev={std_dev}', color='blue')
    plt.fill_between(x_values, pdf_values, color='skyblue', alpha=0.4)

    plt.title(f"Probability Density Function (PDF) of Normal Distribution\nMean = {mean}, Std Dev = {std_dev}")
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid(True)
    plt.show()

mean = 0
std_dev = 1
plot_normal_pdf(mean, std_dev)

# %%
#18
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

def plot_poisson_cdf(lmbda, max_k):
    """
    Plot the CDF of a Poisson distribution.

    Parameters:
    - lmbda: The average rate of occurrences (lambda).
    - max_k: The maximum value of k (the number of occurrences) to plot.
    """
    k_values = np.arange(0, max_k + 1)

    cdf_values = poisson.cdf(k_values, lmbda)

    plt.figure(figsize=(8, 6))
    plt.step(k_values, cdf_values, where='post', label=f'Poisson CDF (λ={lmbda})', color='blue')
    plt.fill_between(k_values, cdf_values, color='skyblue', alpha=0.4)
    plt.title(f"Cumulative Distribution Function (CDF) of Poisson Distribution\nλ = {lmbda}")
    plt.xlabel('Number of occurrences (k)')
    plt.ylabel('Cumulative Probability')
    plt.xticks(k_values)
    plt.legend()
    plt.grid(True)
    plt.show()

def poisson_cdf_value(lmbda, k):
    """
    Calculate and print the CDF value for a specific k.

    Parameters:
    - lmbda: The average rate of occurrences (lambda).
    - k: The number of occurrences.
    """
    cdf_val = poisson.cdf(k, lmbda)
    print(f"CDF for k = {k} (λ = {lmbda}): {cdf_val:.4f}")
    return cdf_val

lmbda = 3
max_k = 10

plot_poisson_cdf(lmbda, max_k)

k = 5
poisson_cdf_value(lmbda, k)
# Out:
# CDF for k = 5 (λ = 3): 0.9161
# np.float64(0.9160820579686966)

# %%
#19
import numpy as np
import matplotlib.pyplot as plt

def simulate_uniform_distribution(a, b, size=10000):
    """
    Simulate a random variable using a continuous uniform distribution.

    Parameters:
    - a: The lower bound of the distribution.
    - b: The upper bound of the distribution.
    - size: The number of random variables to simulate.

    Returns:
    - A numpy array of simulated random variables.
    """
    return np.random.uniform(a, b, size)

def calculate_expected_value(a, b):
    """
    Calculate the theoretical expected value of a uniform distribution.

    Parameters:
    - a: The lower bound of the distribution.
    - b: The upper bound of the distribution.

    Returns:
    - The expected value (mean) of the distribution.
    """
    return (a + b) / 2


a = 2
b = 8
random_variables = simulate_uniform_distribution(a, b, size=10000)

theoretical_expected_value = calculate_expected_value(a, b)

sample_expected_value = np.mean(random_variables)

print(f"Theoretical Expected Value: {theoretical_expected_value}")
print(f"Sample Expected Value (from simulation): {sample_expected_value}")

plt.figure(figsize=(8, 6))
plt.hist(random_variables, bins=50, density=True, alpha=0.6, color='b')
plt.axvline(theoretical_expected_value, color='r', linestyle='dashed', linewidth=2, label=f'Theoretical Mean = {theoretical_expected_value}')
plt.title("Simulated Uniform Distribution")
plt.xlabel("Random Variable Value")
plt.ylabel("Density")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Theoretical Expected Value: 5.0
# Sample Expected Value (from simulation): 4.976456137419673

# %%
#20
import numpy as np
import matplotlib.pyplot as plt

def compare_standard_deviations(data1, data2):
    """
    Compare the standard deviations of two datasets and visualize the difference.

    Parameters:
    - data1: First dataset (array-like).
    - data2: Second dataset (array-like).
    """
    std_dev_1 = np.std(data1)
    std_dev_2 = np.std(data2)

    print(f"Standard Deviation of Dataset 1: {std_dev_1:.2f}")
    print(f"Standard Deviation of Dataset 2: {std_dev_2:.2f}")

    plt.figure(figsize=(14, 6))

    plt.subplot(1, 2, 1)
    plt.hist(data1, bins=20, alpha=0.7, color='blue', edgecolor='black')
    plt.title(f"Histogram of Dataset 1 (Std Dev = {std_dev_1:.2f})")
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.subplot(1, 2, 2)
    plt.hist(data2, bins=20, alpha=0.7, color='green', edgecolor='black')
    plt.title(f"Histogram of Dataset 2 (Std Dev = {std_dev_2:.2f})")
    plt.xlabel('Value')
    plt.ylabel('Frequency')

    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(8, 6))
    plt.boxplot([data1, data2], vert=True, patch_artist=True, labels=['Dataset 1', 'Dataset 2'])
    plt.title("Boxplot Comparison of Datasets")
    plt.ylabel('Values')
    plt.show()

dataset_1 = np.random.normal(loc=0, scale=2, size=1000)
dataset_2 = np.random.normal(loc=0, scale=5, size=1000)
compare_standard_deviations(dataset_1, dataset_2)
# Out:
# Standard Deviation of Dataset 1: 1.92
# Standard Deviation of Dataset 2: 5.10
# <ipython-input-14-2ba24fa065f6>:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], vert=True, patch_artist=True, labels=['Dataset 1', 'Dataset 2'])

# %%
#21
import numpy as np

def calculate_range_and_iqr(data):
    """
    Calculate the range and interquartile range (IQR) of a given dataset.

    Parameters:
    - data: The dataset (array-like).

    Returns:
    - range_value: The range of the dataset.
    - iqr_value: The interquartile range (IQR) of the dataset.
    """
    range_value = np.max(data) - np.min(data)

    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)

    iqr_value = Q3 - Q1

    return range_value, iqr_value

np.random.seed(0)
mean = 0
std_dev = 1
size = 1000
data = np.random.normal(loc=mean, scale=std_dev, size=size)

range_value, iqr_value = calculate_range_and_iqr(data)

print(f"Range of the dataset: {range_value:.2f}")
print(f"Interquartile Range (IQR) of the dataset: {iqr_value:.2f}")
# Out:
# Range of the dataset: 5.81
# Interquartile Range (IQR) of the dataset: 1.31

# %%
#22
import numpy as np
import matplotlib.pyplot as plt

def z_score_normalization(data):
    """
    Apply Z-score normalization (standardization) to a dataset.

    Parameters:
    - data: The dataset (array-like).

    Returns:
    - normalized_data: The Z-score normalized dataset.
    """
    mean = np.mean(data)
    std_dev = np.std(data)

    normalized_data = (data - mean) / std_dev

    return normalized_data

def plot_comparison(original_data, normalized_data):
    """
    Plot the original and normalized datasets for comparison.

    Parameters:
    - original_data: The original dataset.
    - normalized_data: The Z-score normalized dataset.
    """
    plt.figure(figsize=(14, 6))

    plt.subplot(1, 2, 1)
    plt.hist(original_data, bins=20, alpha=0.7, color='blue', edgecolor='black')
    plt.title("Original Data")
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.subplot(1, 2, 2)
    plt.hist(normalized_data, bins=20, alpha=0.7, color='green', edgecolor='black')
    plt.title("Z-score Normalized Data")
    plt.xlabel("Value")
    plt.ylabel("Frequency")

    plt.tight_layout()
    plt.show()

np.random.seed(0)
mean = 50
std_dev = 15
size = 1000

original_data = np.random.normal(loc=mean, scale=std_dev, size=size)

normalized_data = z_score_normalization(original_data)

plot_comparison(original_data, normalized_data)

print(f"Original Data - Mean: {np.mean(original_data):.2f}, Std Dev: {np.std(original_data):.2f}")
print(f"Normalized Data - Mean: {np.mean(normalized_data):.2f}, Std Dev: {np.std(normalized_data):.2f}")
# Out:
# Original Data - Mean: 49.32, Std Dev: 14.81
# Normalized Data - Mean: 0.00, Std Dev: 1.00

# %%
#23
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def calculate_skewness_and_kurtosis(data):
    """
    Calculate the skewness and kurtosis of a given dataset.

    Parameters:
    - data: The dataset (array-like).

    Returns:
    - skewness: The skewness of the dataset.
    - kurtosis: The kurtosis of the dataset.
    """
    skewness = stats.skew(data)
    kurtosis = stats.kurtosis(data)

    return skewness, kurtosis

np.random.seed(0)
mean = 0
std_dev = 1
size = 1000

data = np.random.normal(loc=mean, scale=std_dev, size=size)

skewness, kurtosis = calculate_skewness_and_kurtosis(data)

print(f"Skewness: {skewness:.4f}")
print(f"Kurtosis: {kurtosis:.4f}")

plt.figure(figsize=(8, 6))
plt.hist(data, bins=30, color='blue', alpha=0.7, edgecolor='black')
plt.title(f"Normal Distribution\nSkewness: {skewness:.4f}, Kurtosis: {kurtosis:.4f}")
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
